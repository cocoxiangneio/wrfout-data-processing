# %%
import pandas as pd

# Create the data frame
data_combined = {
    "微物理方案": ["Thompson (Thompson et al., 2008)", 
             "WSM6 (Hong and Lim, 2006)",
             "WSM6 (Hong and Lim, 2006)",
             "WSM6 (Hong and Lim, 2006)",
             "WSM6 (Hong and Lim, 2006)",
             "WSM6 (Hong and Lim, 2006)",
             "WSM6 (Hong and Lim, 2006)",
             "WSM6 (Hong and Lim, 2006)",
             "WSM6 (Hong and Lim, 2006)",
             "WSM6 (Hong and Lim, 2006)"],
    "积云对流方案": ["NONE", 
             "Kain-Fritsch (Kain, 2004)", 
             "Grell-3 (Grell, 1993)",
             "New Tiedtke (Zhang et al., 2011)",
             "KF-CuP (Berg et al., 2013)",
             "New Tiedtke (Zhang et al., 2011)",
             "Betts-Miller-Janjic (Janjić, 1994)",
             "Grell-Freitas (Grell and Freitas, 2014)",
             "Multi-scale KF (Zheng et al., 2016)",
             "KIAPS SAS (Kwon and Hong, 2017)"]
}

df_combined = pd.DataFrame(data_combined)

# Save to Excel file
file_path_combined = "C:/Users/xmxm/Desktop/微物理方案与积云对流方案组合.xlsx"
df_combined.to_excel(file_path_combined, index=False)

file_path_combined
# Out:
# 'C:/Users/xmxm/Desktop/微物理方案与积云对流方案组合.xlsx'

# %%
import pandas as pd

# Create the data frame
data_combined = {
    "微物理方案": ["Thompson (Thompson et al., 2008)", 
             "WSM6 (Hong and Lim, 2006)",
             "Thompson (Thompson et al., 2008)", 
             "WSM6 (Hong and Lim, 2006)",
             "Thompson (Thompson et al., 2008)", 
             "WSM6 (Hong and Lim, 2006)",
             "Thompson (Thompson et al., 2008)", 
             "WSM6 (Hong and Lim, 2006)",
             "Thompson (Thompson et al., 2008)", 
             "WSM6 (Hong and Lim, 2006)",
             "Thompson (Thompson et al., 2008)", 
             "WSM6 (Hong and Lim, 2006)",
             "Thompson (Thompson et al., 2008)", 
             "WSM6 (Hong and Lim, 2006)",
             "Thompson (Thompson et al., 2008)", 
             "WSM6 (Hong and Lim, 2006)",
             "Thompson (Thompson et al., 2008)", 
             "WSM6 (Hong and Lim, 2006)"],
    "积云对流方案": ["NONE", 
             "NONE", 
             "Kain-Fritsch (Kain, 2004)", 
             "Kain-Fritsch (Kain, 2004)",
             "Grell-3 (Grell, 1993)",
             "Grell-3 (Grell, 1993)",
             "New Tiedtke (Zhang et al., 2011)",
             "New Tiedtke (Zhang et al., 2011)",
             "KF-CuP (Berg et al., 2013)",
             "KF-CuP (Berg et al., 2013)",
             "Betts-Miller-Janjic (Janjić, 1994)",
             "Betts-Miller-Janjic (Janjić, 1994)",
             "Grell-Freitas (Grell and Freitas, 2014)",
             "Grell-Freitas (Grell and Freitas, 2014)",
             "Multi-scale KF (Zheng et al., 2016)",
             "Multi-scale KF (Zheng et al., 2016)",
             "KIAPS SAS (Kwon and Hong, 2017)",
             "KIAPS SAS (Kwon and Hong, 2017)"]
}

df_combined = pd.DataFrame(data_combined)

# Save to Excel file
file_path_combined ="C:/Users/xmxm/Desktop/微物理方案与积云对流方案组合.xlsx"
df_combined.to_excel(file_path_combined, index=False)

file_path_combined
# Out:
# 'C:/Users/xmxm/Desktop/微物理方案与积云对流方案组合.xlsx'
