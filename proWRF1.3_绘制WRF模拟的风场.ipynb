# %%
from wrf import to_np, getvar, uvmet, latlon_coords, geo_bounds, get_cartopy, cartopy_xlim, cartopy_ylim
import numpy as np
import pandas as pd
from datetime import datetime
import xarray as xr
from metpy.units import units
from metpy.calc import height_to_geopotential, geopotential_to_height
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
from matplotlib.colors import from_levels_and_colors
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader
from cartopy.feature import NaturalEarthFeature
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
from cartopy.mpl.gridliner import LATITUDE_FORMATTER, LONGITUDE_FORMATTER
import shapely.geometry as sgeom
import cmaps
from glob import glob
from copy import copy
from netCDF4 import Dataset
# Out:
# D:\conda\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
#   "class": algorithms.Blowfish,

# %%
f=("E:/000_FuJian/wrfout_FuJian/A1_mp8_cu0/1wrfout_d02.nc")
ncfile = Dataset(f)
lon = np.array(ncfile['XLONG'])[0,:,:]
lat = np.array(ncfile['XLAT'])[0,:,:]
# 提取WRF模拟的投影设置
wrf_proj = get_cartopy(u10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       4 lat = np.array(ncfile['XLAT'])[0,:,:]
#       5 # 提取WRF模拟的投影设置
# ----> 6 wrf_proj = get_cartopy(u10)
#
# NameError: name 'u10' is not defined

# %%
# 21创建画布
fig = plt.figure(figsize=(10,8))
# 设置地图投影
ax = plt.axes(projection=wrf_proj)
# 设置地图范围
ax.set_xlim(cartopy_xlim(u10))
ax.set_ylim(cartopy_ylim(u10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 fig = plt.figure(figsize=(10,8))
#       3 # 设置地图投影
# ----> 4 ax = plt.axes(projection=wrf_proj)
#       5 # 设置地图范围
#       6 ax.set_xlim(cartopy_xlim(u10))
#
# NameError: name 'wrf_proj' is not defined
