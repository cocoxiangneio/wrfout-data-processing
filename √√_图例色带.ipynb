# %%
# Correcting the code by using the correct method to create a colorbar
import matplotlib.colorbar as mcolorbar

# Create a horizontal colorbar
fig, ax = plt.subplots(figsize=(10, 0.5))
cb = mcolorbar.ColorbarBase(ax, cmap=cmap, norm=norm, orientation='horizontal')
cb.set_ticks(clevs)
cb.set_ticklabels([str(level) for level in clevs])  # set the tick labels

# Show the plot
plt.show()
