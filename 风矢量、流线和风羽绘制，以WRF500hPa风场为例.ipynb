# %%
# %config InlineBackend.figure_format = 'retina'

# %%
import numpy as np
import xarray as xr

file_path = "E:/000_FuJian/wrfout_FuJian/A1_mp8_cu0/1wrfout_d03.nc"
ds = xr.open_dataset(file_path)

time_coord = ds.coords['Time']
u = ds['U'].sel(level=500, Time=[0])
v = ds['V'].sel(level=500, Time=[0])
wspd = np.sqrt(u**2 + v**2)
wspd.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 8
#       5 ds = xr.open_dataset(file_path)
#       7 time_coord = ds.coords['Time']
# ----> 8 u = ds['U'].sel(level=500, Time=[0])
#       9 v = ds['V'].sel(level=500, Time=[0])
#      10 wspd = np.sqrt(u**2 + v**2)
#
# File D:\conda\Lib\site-packages\xarray\core\dataarray.py:1550, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1440 def sel(
#    1441     self: T_DataArray,
#    1442     indexers: Mapping[Any, Any] | None = None,
#    (...)
#    1446     **indexers_kwargs: Any,
#    1447 ) -> T_DataArray:
#    1448     """Return a new DataArray whose data is given by selecting index
#    1449     labels along the specified dimension(s).
#    1450
#    (...)
#    1548     Dimensions without coordinates: points
#    1549     """
# -> 1550     ds = self._to_temp_dataset().sel(
# ...
